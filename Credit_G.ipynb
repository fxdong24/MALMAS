# %%
from data_file.Credit_G import Credit_G as read_data
from baselines.baseline_func import run_baseline_experiments
import global_config
from main_demo.model_factory import set_params, get_model
from main_demo.main_func import *
from main_demo.pipeline import *

prompt_path_list = global_config.prompt_path_list
task_name = "Credit_G"
task = "classification"
# Out:
# 2025-08-04 15:43:31,511 INFO: No config file found at C:\Users\lenovo\.openml\config, using default configuration.

# %%
from baselines.baseline_func import run_baseline_experiments_for_other_model
baseline_summary_auc = run_baseline_experiments_for_other_model(
    
    task=task,
    model_name="xgboost",
    task_name=task_name,
    read_data_class=read_data,
    other_model="gpt_41_mini",
    metric="auc",
    verbose=False
)
baseline_summary_auc
# Out:
#                      0         1         2      mean       std
# xgboost_base  0.756220  0.750625  0.760340  0.755728  0.003981
# DFS           0.774345  0.753006  0.747780  0.758377  0.011491
# AutoFeat      0.756220  0.750625  0.760340  0.755728  0.003981
# OpenFE        0.766190  0.758214  0.740214  0.754873  0.010865
# CAAFE         0.759851  0.748304  0.771405  0.759853  0.009431
# OCTree        0.750268  0.759048  0.752893  0.754070  0.003680
# LLMFE         0.757500  0.751637  0.759472  0.756203  0.003328

# %%
MALMAS_summary_auc_gpt4o = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=4,
    
    temp=1.0,
    other_model="gpt_41_mini",
    verbose=False
    
)
MALMAS_summary_auc_gpt4o
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                      0         1        2      mean       std
# xgboost_base  0.756220  0.750625  0.76034  0.755728  0.003981
# MALMAS(ours)  0.761786  0.760208  0.76958  0.763858  0.004097

# %%
from main_demo.ablations import MALMAS_random_experiments_without_memory_async
res = pd.DataFrame()
for i in range(len(prompt_path_list)):
    prompt_path_sublist = prompt_path_list[:i+1]
    r = await MALMAS_random_experiments_without_memory_async(
        task_name=task_name,
        task=task,
        read_data_class=read_data,
        model_name="xgboost",
        metric="auc",
        prompt_path_list=prompt_path_sublist,
        Nround=4,
        
        temp=1.0,
        verbose=False,
        placeholder=i+1
    )
    if i == 0:
        res = pd.concat([res, r], axis=0)
    else:
        res = pd.concat([res, r[1:]], axis=0)

res
# Out:
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
#                      0         1         2      mean       std
# xgboost_base  0.756220  0.750625  0.760340  0.755728  0.003981
# MALMAS(ours)  0.755536  0.754315  0.757499  0.755783  0.001311
# MALMAS(ours)  0.746250  0.747262  0.762792  0.752101  0.007571
# MALMAS(ours)  0.737470  0.745417  0.767278  0.750055  0.012603
# MALMAS(ours)  0.739137  0.765506  0.766590  0.757078  0.012694
# MALMAS(ours)  0.746339  0.760982  0.769969  0.759097  0.009739
# MALMAS(ours)  0.752946  0.763571  0.778163  0.764894  0.010337

# %%
baseline_summary_auc = run_baseline_experiments(
    
    task=task,
    model_name="xgboost",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc
# Out:
#                      0         1         2      mean       std
# xgboost_base  0.756220  0.750625  0.760340  0.755728  0.003981
# DFS           0.774345  0.753006  0.747780  0.758377  0.011491
# AutoFeat      0.756220  0.750625  0.760340  0.755728  0.003981
# OpenFE        0.766190  0.758214  0.740214  0.754873  0.010865
# CAAFE         0.753274  0.740833  0.760340  0.751482  0.008064
# OCTree        0.738929  0.764226  0.760340  0.754498  0.011123
# LLMFE         0.746101  0.726220  0.771046  0.747789  0.018339

# %%
MALMAS_summary_auc = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=4,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                      0         1         2      mean       std
# xgboost_base  0.756220  0.750625  0.760340  0.755728  0.003981
# MALMAS(ours)  0.773423  0.772738  0.777386  0.774515  0.002049

# %%
baseline_summary_acc = run_baseline_experiments(
    
    task=task,
    model_name="xgboost",
    task_name=task_name,
    read_data_class=read_data,
    metric="acc",
    verbose=False
)
baseline_summary_acc
# Out:
#                    0       1       2      mean       std
# xgboost_base  0.7275  0.7400  0.7650  0.744167  0.015590
# DFS           0.7500  0.7300  0.7575  0.745833  0.011607
# AutoFeat      0.7275  0.7400  0.7650  0.744167  0.015590
# OpenFE        0.7350  0.7450  0.7350  0.738333  0.004714
# CAAFE         0.7525  0.7525  0.7650  0.756667  0.005893
# OCTree        0.7350  0.7225  0.7650  0.740833  0.017834
# LLMFE         0.7575  0.7150  0.7700  0.747500  0.023541

# %%
MALMAS_summary_acc = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="acc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_acc
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                    0       1      2      mean       std
# xgboost_base  0.7275  0.7400  0.765  0.744167  0.015590
# MALMAS(ours)  0.7425  0.7375  0.760  0.746667  0.009647

# %%
baseline_summary_auc_m = run_baseline_experiments(
    
    task=task,
    model_name="lightgbm",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc_m
# Out:
#                       0         1         2      mean       std
# lightgbm_base  0.741786  0.754554  0.753282  0.749874  0.005743
# DFS            0.766071  0.741577  0.738658  0.748769  0.012292
# AutoFeat       0.741786  0.759345  0.753282  0.751471  0.007282
# OpenFE         0.757113  0.787262  0.742576  0.762317  0.018610
# CAAFE          0.760655  0.749821  0.753282  0.754586  0.004518
# OCTree         0.745387  0.740893  0.753282  0.746521  0.005121
# LLMFE          0.738810  0.745089  0.749006  0.744301  0.004200

# %%
MALMAS_summary_auc_m = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="lightgbm",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc_m
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                       0         1         2      mean       std
# lightgbm_base  0.741786  0.754554  0.753282  0.749874  0.005743
# MALMAS(ours)   0.761042  0.752887  0.785759  0.766563  0.013976

# %%
baseline_summary_auc_c = run_baseline_experiments(
    
    task=task,
    model_name="mlp",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc_c
# Out:
#                       0         1         2      mean       std
# mlp_base  0.775208  0.789167  0.767338  0.777238  0.009026
# DFS            0.779732  0.785506  0.769012  0.778083  0.006834
# AutoFeat       0.773542  0.777857  0.766381  0.772593  0.004733
# OpenFE         0.784881  0.784613  0.765274  0.778256  0.009180
# CAAFE          0.780208  0.776935  0.767338  0.774827  0.005462
# OCTree         0.763185  0.771994  0.767338  0.767505  0.003598
# LLMFE          0.779167  0.778393  0.772152  0.776571  0.003140

# %%
MALMAS_summary_auc_c = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="mlp",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc_c
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                       0         1         2      mean       std
# mlp_base  0.775208  0.789167  0.767338  0.777238  0.009026
# MALMAS(ours)   0.786071  0.786071  0.778313  0.783485  0.003657

# %%
baseline_summary_auc_r = run_baseline_experiments(
    
    task=task,
    model_name="random_forest",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc_r
# Out:
#                            0         1         2      mean       std
# random_forest_base  0.776295  0.766949  0.760295  0.767846  0.006563
# DFS                 0.765967  0.752708  0.758859  0.759178  0.005418
# AutoFeat            0.766845  0.748676  0.761581  0.759034  0.007633
# OpenFE              0.778750  0.772530  0.748587  0.766622  0.013003
# CAAFE               0.779583  0.733512  0.760295  0.757797  0.018891
# OCTree              0.771012  0.735149  0.760295  0.755485  0.015031
# LLMFE               0.765908  0.758512  0.769745  0.764722  0.004662

# %%
MALMAS_summary_auc_r = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="random_forest",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc_r
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                            0         1         2      mean       std
# random_forest_base  0.776295  0.766949  0.760295  0.767846  0.006563
# MALMAS(ours)        0.770759  0.772411  0.762882  0.768684  0.004158

# %%
import time
time.sleep(2000)
set_params(compute_tokens=False)
start=time.time()
await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    random_states_list=[100],
    temp=1.0,
    verbose=False
)
end=time.time()
print("total_times\t",(end-start)/3600)

print("total_tokens\t",global_config.total_tokens//1000)
# Out:
# Loaded local folder: D:\code_management\idea\mypro\data_file\Credit_G
#
# ================ Initialized AgentMemory ================
#
#
# 🔁  ===== The 1-th round =====
# 2025-07-28 09:50:30,465 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:50:30,468 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:50:30,468 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:50:30,469 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:50:30,469 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:50:30,469 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:50:57,447 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:50:58,315 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:51:04,664 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:51:06,005 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:51:11,423 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:51:15,621 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error unaryfeature agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-28 09:51:16,747 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# ⚠️ [localpattern]Effective feature count 0 is less than min_effective(2), skipping LLM-generated conceptual summary.
# ⚠️ [temporalfeature]Effective feature count 0 is less than min_effective(2), skipping LLM-generated conceptual summary.
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-28 09:52:00,162 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error unaryfeature agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-28 09:52:09,683 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-28 09:52:27,039 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error crosscompositional agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-28 09:52:35,181 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# ⚠️ [unaryfeature]Effective feature count 1 is less than min_effective(2), skipping LLM-generated conceptual summary.
# [❌code error crosscompositional agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-28 09:53:33,367 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error crosscompositional agent] could not convert string to float: '1<=X<4'
# 2025-07-28 09:54:31,609 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:55:10,011 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error crosscompositional agent] '<' not supported between instances of 'int' and '
# 2025-07-28 09:55:42,983 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error crosscompositional agent] could not convert string to float: '1<=X<4'
# 2025-07-28 09:56:17,184 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [crosscompositional] Generating local conceptual summary ...
# 2025-07-28 09:57:02,086 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝  Generating global conceptual summary...
# 2025-07-28 09:57:11,818 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 🔁  ===== The 2-th round =====
# 2025-07-28 09:57:24,358 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:24,359 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:24,359 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:24,360 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:24,360 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:24,361 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:43,917 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:50,116 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:57:59,482 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# ⚠️ [temporalfeature]Effective feature count 0 is less than min_effective(2), skipping LLM-generated conceptual summary.
# 2025-07-28 09:58:08,651 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:58:08,652 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 09:58:08,800 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-28 09:58:21,036 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [crosscompositional] Generating local conceptual summary ...
# 2025-07-28 09:58:51,604 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [unaryfeature] Generating local conceptual summary ...
# 2025-07-28 09:59:15,259 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error localpattern agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-28 09:59:24,782 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-28 09:59:42,857 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error localpattern agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-28 09:59:56,121 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error localpattern agent] Bin labels must be one fewer than the number of bi
# 2025-07-28 10:00:25,914 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:01:06,977 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localpattern] Generating local conceptual summary ...
# 2025-07-28 10:02:01,199 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝  Generating global conceptual summary...
# 2025-07-28 10:02:09,747 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 🔁  ===== The 3-th round =====
# 2025-07-28 10:02:23,777 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:23,778 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:23,778 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:23,779 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:23,779 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:23,780 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:48,353 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:49,683 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:57,978 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:59,620 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:02:59,718 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-28 10:03:19,585 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error temporalfeature agent] unsupported operand type(s) for -: 'float' and 'st
# 2025-07-28 10:03:27,776 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:03:27,777 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-28 10:03:43,547 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localpattern] Generating local conceptual summary ...
# 2025-07-28 10:04:07,870 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:04:34,594 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [unaryfeature] Generating local conceptual summary ...
# ⚠️ [temporalfeature]Effective feature count 0 is less than min_effective(2), skipping LLM-generated conceptual summary.
# 📝 [crosscompositional] Generating local conceptual summary ...
# 2025-07-28 10:05:17,447 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝  Generating global conceptual summary...
# 2025-07-28 10:05:28,713 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 🔁  ===== The 4-th round =====
# 2025-07-28 10:05:45,007 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:05:45,023 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:05:45,029 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:05:45,035 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:05:45,094 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:05:46,222 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:06:16,587 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:06:17,351 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:06:20,372 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:06:21,242 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:06:21,857 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:06:36,396 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-28 10:07:03,942 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# ⚠️ [temporalfeature]Skipping. All newly generated features have been evaluated.
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-28 10:07:25,525 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# ⚠️ [crosscompositional]Skipping. All newly generated features have been evaluated.
# ⚠️ 依赖注入失败: `from jenkspy import jenks_breaks` -> No module named 'jenkspy'
# [❌code error localpattern agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-28 10:07:35,379 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [unaryfeature] Generating local conceptual summary ...
# 2025-07-28 10:07:55,605 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-28 10:08:35,488 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localpattern] Generating local conceptual summary ...
#
# 📝  Generating global conceptual summary...
# 2025-07-28 10:08:46,139 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# total_times	 0.31036966429816354
# total_tokens	 181
