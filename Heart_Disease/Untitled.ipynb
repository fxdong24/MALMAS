# %%
import pandas as pd
from typing import Dict, List, Union
import numpy as np

# %%
df=pd.read_csv("Heart_Disease.csv").sample(frac=1, random_state=42)  # 可以是任意整数

# %%
df.to_csv("Heart_Disease.csv",index=False)
