# %%
import pandas as pd

# %%
import pandas as pd
import json

# Load the uploaded dataset
file_path = 'Heart_Disease.csv'
df = pd.read_csv(file_path)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df=expand_mushroom_dataset(df)

# %%
df.columns=[i.replace("-","_") for i in df.columns]

# %%
df.to_csv("Mushroom.csv",index=False)

# %%
import json
import pandas as pd

def fill_values_from_data(schema, df):
    """
    根据DataFrame数据自动填充JSON schema中的values字段
    
    参数:
    schema: dict - 原始schema描述
    df: pd.DataFrame - 数据
    
    返回:
    dict - 带有填充values字段的schema
    """
    filled_schema = schema.copy()
    
    for col in df.columns:
        if col in filled_schema:
            col_type = filled_schema[col]["type"]
            
            # 只处理分类和有序变量
            if col_type in ["categorical", "ordinal"]:
                # 获取唯一值并排序
                unique_values = sorted(df[col].dropna().unique())
                
                # 转换为字符串形式(避免JSON序列化问题)
                unique_values = [str(v) for v in unique_values]
                
                filled_schema[col]["values"] = unique_values
    
    return filled_schema





with open('parsed_description.json',"r") as f:
    schema = json.load(f)


df = pd.read_csv('Employee_Attrition.csv')

filled_schema = fill_values_from_data(schema, df)
df = transform_features(df)
with open('parsed_description.json', 'w') as f:
    json.dump(filled_schema, f, indent=2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   object
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %%
enrich_feature_meta(
    csv_path="Balance_Scale.csv",
    json_path="balance-scale-metadata.json",
    output_path="parsed_description.json"
)
# Out:
# ✅ 已保存 enriched metadata 至：parsed_description.json
