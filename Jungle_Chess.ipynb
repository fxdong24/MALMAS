# %%
from data_file.Jungle_Chess import Jungle_Chess as read_data
from baselines.baseline_func import run_baseline_experiments
import global_config
from main_demo.model_factory import set_params, get_model
from main_demo.main_func import *
from main_demo.pipeline import *

prompt_path_list = global_config.prompt_path_list
task_name = "Jungle_Chess"
task = "classification"
# Out:
# 2025-08-04 15:44:43,807 INFO: No config file found at C:\Users\lenovo\.openml\config, using default configuration.

# %%
from baselines.baseline_func import run_baseline_experiments_for_other_model
baseline_summary_auc = run_baseline_experiments_for_other_model(
    
    task=task,
    model_name="xgboost",
    task_name=task_name,
    read_data_class=read_data,
    other_model="gpt_41_mini",
    metric="auc",
    verbose=False
)
baseline_summary_auc
# Out:
#                      0         1         2      mean       std
# xgboost_base  0.969985  0.969845  0.969780  0.969870  0.000086
# DFS           0.974448  0.975390  0.974892  0.974910  0.000385
# AutoFeat      0.969985  0.969845  0.969780  0.969870  0.000086
# OpenFE        0.980463  0.980375  0.979668  0.980168  0.000356
# CAAFE         0.987171  0.975559  0.972710  0.978480  0.006254
# OCTree        0.972242  0.977628  0.972623  0.974164  0.002454
# LLMFE         0.983952  0.983717  0.984042  0.983904  0.000137

# %%
MALMAS_summary_auc_gpt4o = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=4,
    
    temp=1.0,
    other_model="gpt_41_mini",
    verbose=False
    
)
MALMAS_summary_auc_gpt4o
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                      0         1        2      mean       std
# xgboost_base  0.969985  0.969845  0.96978  0.969870  0.000086
# MALMAS(ours)  0.988313  0.984892  0.99227  0.988492  0.003015

# %%
from main_demo.ablations import MALMAS_random_experiments_without_memory_async
res = pd.DataFrame()
for i in range(len(prompt_path_list)):
    prompt_path_sublist = prompt_path_list[:i+1]
    r = await MALMAS_random_experiments_without_memory_async(
        task_name=task_name,
        task=task,
        read_data_class=read_data,
        model_name="xgboost",
        metric="auc",
        prompt_path_list=prompt_path_sublist,
        Nround=4,
        
        temp=1.0,
        verbose=False,
        placeholder=i+1
    )
    if i == 0:
        res = pd.concat([res, r], axis=0)
    else:
        res = pd.concat([res, r[1:]], axis=0)

res
# Out:
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
# [MALMAS Ablation] Loaded cached feature.
#                      0         1         2      mean       std
# xgboost_base  0.969985  0.969845  0.969780  0.969870  0.000086
# MALMAS(ours)  0.973059  0.971900  0.972000  0.972320  0.000525
# MALMAS(ours)  0.990822  0.997187  0.990026  0.992678  0.003205
# MALMAS(ours)  0.987279  0.961209  0.985459  0.977982  0.011883
# MALMAS(ours)  0.988415  0.966739  0.985169  0.980108  0.009545
# MALMAS(ours)  0.978398  0.988449  0.995180  0.987343  0.006896
# MALMAS(ours)  0.979979  0.991213  0.985371  0.985521  0.004587

# %%
baseline_summary_auc = run_baseline_experiments(
    
    task=task,
    model_name="xgboost",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc
# Out:
#                      0         1         2      mean       std
# xgboost_base  0.969985  0.969845  0.969780  0.969870  0.000086
# DFS           0.974448  0.975390  0.974892  0.974910  0.000385
# AutoFeat      0.969985  0.969845  0.969780  0.969870  0.000086
# OpenFE        0.980463  0.980375  0.979668  0.980168  0.000356
# CAAFE         0.975784  0.984727  0.988509  0.983007  0.005336
# OCTree        0.969985  0.977136  0.969780  0.972300  0.003420
# LLMFE         0.975136  0.978308  0.989096  0.980847  0.005975

# %%
MALMAS_summary_auc = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=4,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                      0         1         2      mean       std
# xgboost_base  0.969985  0.969845  0.969780  0.969870  0.000086
# MALMAS(ours)  0.992878  0.993131  0.993675  0.993228  0.000333

# %%
baseline_summary_acc = run_baseline_experiments(
    
    task=task,
    model_name="xgboost",
    task_name=task_name,
    read_data_class=read_data,
    metric="acc",
    verbose=False
)
baseline_summary_acc
# Out:
#                      0         1         2      mean       std
# xgboost_base  0.854641  0.854697  0.854250  0.854529  0.000199
# DFS           0.866410  0.870091  0.868083  0.868195  0.001505
# AutoFeat      0.854641  0.854697  0.854250  0.854529  0.000199
# OpenFE        0.885821  0.882084  0.879351  0.882419  0.002652
# CAAFE         0.872936  0.904228  0.926930  0.901365  0.022136
# OCTree        0.854641  0.889447  0.854250  0.866113  0.016500
# LLMFE         0.871932  0.884929  0.928548  0.895136  0.024214

# %%
MALMAS_summary_acc = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="acc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_acc
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                      0         1         2      mean       std
# xgboost_base  0.854641  0.854697  0.854250  0.854529  0.000199
# MALMAS(ours)  0.946118  0.947345  0.949409  0.947624  0.001358

# %%
baseline_summary_auc_m = run_baseline_experiments(
    
    task=task,
    model_name="lightgbm",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc_m
# Out:
#                       0         1         2      mean       std
# lightgbm_base  0.974256  0.973722  0.973229  0.973736  0.000419
# DFS            0.979082  0.980005  0.979034  0.979374  0.000447
# AutoFeat       0.974256  0.973722  0.973229  0.973736  0.000419
# OpenFE         0.984213  0.983877  0.984163  0.984084  0.000148
# CAAFE          0.980290  0.989771  0.992822  0.987628  0.005336
# OCTree         0.974256  0.984555  0.973229  0.977347  0.005114
# LLMFE          0.981754  0.983746  0.994848  0.986783  0.005761

# %%
MALMAS_summary_auc_m = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="lightgbm",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc_m
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                       0         1         2      mean       std
# lightgbm_base  0.974256  0.973722  0.973229  0.973736  0.000419
# MALMAS(ours)   0.995997  0.996416  0.996198  0.996204  0.000171

# %%
baseline_summary_auc_c = run_baseline_experiments(
    
    task=task,
    model_name="mlp",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc_c
# Out:
#                       0         1         2      mean       std
# mlp_base  0.974055  0.974425  0.973794  0.974091  0.000259
# DFS            0.976611  0.977564  0.976309  0.976828  0.000535
# AutoFeat       0.974198  0.974349  0.974190  0.974246  0.000073
# OpenFE         0.982023  0.980521  0.980616  0.981053  0.000687
# CAAFE          0.978655  0.991674  0.995932  0.988754  0.007349
# OCTree         0.974055  0.988710  0.973794  0.978853  0.006971
# LLMFE          0.984473  0.986262  0.997400  0.989378  0.005719

# %%
MALMAS_summary_auc_c = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="mlp",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc_c
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                       0         1         2      mean       std
# mlp_base  0.974055  0.974425  0.973794  0.974091  0.000259
# MALMAS(ours)   0.997673  0.997694  0.997504  0.997624  0.000085

# %%
baseline_summary_auc_r = run_baseline_experiments(
    
    task=task,
    model_name="random_forest",
    task_name=task_name,
    read_data_class=read_data,
    metric="auc",
    verbose=False
)
baseline_summary_auc_r
# Out:
#                            0         1         2      mean       std
# random_forest_base  0.942274  0.942758  0.942744  0.942592  0.000225
# DFS                 0.954238  0.955076  0.955024  0.954779  0.000383
# AutoFeat            0.948812  0.949700  0.949326  0.949279  0.000364
# OpenFE              0.963459  0.963591  0.962235  0.963095  0.000610
# CAAFE               0.967313  0.980748  0.990018  0.979360  0.009321
# OCTree              0.942274  0.976179  0.942744  0.953733  0.015873
# LLMFE               0.970655  0.961295  0.985172  0.972374  0.009823

# %%
MALMAS_summary_auc_r = await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="random_forest",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    
    temp=1.0,
    verbose=False
)
MALMAS_summary_auc_r
# Out:
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
# [MALMAS] Loaded cached feature.
#                            0         1         2      mean       std
# random_forest_base  0.942274  0.942758  0.942744  0.942592  0.000225
# MALMAS(ours)        0.992174  0.993097  0.992612  0.992628  0.000377

# %%
import time
set_params(compute_tokens=False)
start=time.time()
await MALMAS_random_experiments_async(
    task_name=task_name,
    task=task,
    read_data_class=read_data,
    model_name="xgboost",
    metric="auc",
    prompt_path_list=prompt_path_list,
    Nround=4,
    min_effective=2,
    long_memory_feature_num=3,
    random_states_list=[100],
    temp=1.0,
    verbose=False
)
end=time.time()
print("total_times\t",(end-start)/3600)

print("total_tokens\t",global_config.total_tokens//1000)
# Out:
# Loaded local folder: D:\code_management\idea\mypro\data_file\Jungle_Chess
#
# ================ Initialized AgentMemory ================
#
#
# 🔁  ===== The 1-th round =====
# 2025-07-27 22:46:53,355 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:46:53,357 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:46:53,358 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:46:53,358 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:46:53,358 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:46:53,359 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:47:28,478 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:47:28,629 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:47:29,195 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:47:32,472 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:47:33,188 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:47:38,821 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localpattern] Generating local conceptual summary ...
# 2025-07-27 22:48:42,513 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# ⚠️ [temporalfeature]Effective feature count 0 is less than min_effective(2), skipping LLM-generated conceptual summary.
# 📝 [unaryfeature] Generating local conceptual summary ...
# 2025-07-27 22:50:38,221 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error crosscompositional agent] ufunc 'subtract' did not contain a loop with signa
# 2025-07-27 22:50:48,767 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-27 22:51:53,021 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-27 22:53:23,902 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error crosscompositional agent] ord() expected string of length 1, but float found
# 2025-07-27 22:53:32,709 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [crosscompositional] Generating local conceptual summary ...
# 2025-07-27 22:55:12,344 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝  Generating global conceptual summary...
# 2025-07-27 22:55:22,379 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 🔁  ===== The 2-th round =====
# 2025-07-27 22:55:38,866 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:55:38,867 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:55:38,868 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:55:38,868 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:55:38,869 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:55:38,869 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:56:01,803 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:56:07,742 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:56:07,845 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:56:10,405 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:56:12,146 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 22:56:12,555 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-27 22:57:23,621 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [temporalfeature] Generating local conceptual summary ...
# 2025-07-27 22:58:29,822 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [unaryfeature] Generating local conceptual summary ...
# 2025-07-27 23:00:05,156 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localpattern] Generating local conceptual summary ...
# 2025-07-27 23:01:23,748 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [crosscompositional] Generating local conceptual summary ...
# 2025-07-27 23:02:40,650 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [❌code error localtransform agent] ❌ 编译阶段出错。llm-code原因错误SyntaxError: invalid syntax。
# 2025-07-27 23:02:49,867 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-27 23:04:28,375 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝  Generating global conceptual summary...
# 2025-07-27 23:04:40,458 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 🔁  ===== The 3-th round =====
# 2025-07-27 23:04:56,947 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:04:56,950 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:04:56,955 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:04:56,962 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:04:56,963 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:04:56,986 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:05:24,387 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:05:28,791 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:05:30,429 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:05:30,430 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:05:31,249 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:05:38,826 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [unaryfeature] Generating local conceptual summary ...
# 2025-07-27 23:06:55,011 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [temporalfeature] Generating local conceptual summary ...
# 2025-07-27 23:07:57,832 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localpattern] Generating local conceptual summary ...
# 2025-07-27 23:09:38,648 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-27 23:10:54,731 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-27 23:12:23,409 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# ⚠️ [crosscompositional]Skipping. All newly generated features have been evaluated.
#
# 📝  Generating global conceptual summary...
# 2025-07-27 23:12:38,985 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 🔁  ===== The 4-th round =====
# 2025-07-27 23:12:55,665 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:12:55,665 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:12:55,666 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:12:55,666 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:12:55,667 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:12:55,667 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:13:21,469 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:13:25,896 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:13:27,818 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:13:27,819 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:13:30,788 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2025-07-27 23:13:41,437 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [temporalfeature] Generating local conceptual summary ...
# 2025-07-27 23:15:05,507 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localpattern] Generating local conceptual summary ...
# 2025-07-27 23:16:41,353 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [unaryfeature] Generating local conceptual summary ...
# 2025-07-27 23:18:57,135 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [aggregationconstruct] Generating local conceptual summary ...
# 2025-07-27 23:20:07,488 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [crosscompositional] Generating local conceptual summary ...
# 2025-07-27 23:21:40,458 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝 [localtransform] Generating local conceptual summary ...
# 2025-07-27 23:23:49,993 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 📝  Generating global conceptual summary...
# 2025-07-27 23:24:00,643 INFO: HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# total_times	 0.6286013823747635
# total_tokens	 118
